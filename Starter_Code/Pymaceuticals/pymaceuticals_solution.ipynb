# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
merge_df = pd.merge(mouse_metadata,study_results,on = "Mouse ID", how='inner')

# Display the data table for preview
merge_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint
# 0        k403     Ramicane  Male          21          16          0  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
len(merge_df['Mouse ID'].unique())
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse = merge_df.duplicated(subset= ['Mouse ID','Timepoint'])
duplicate_mouse_id = merge_df.loc[duplicate_mouse == True, "Mouse ID"].unique()
duplicate_mouse_id
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse_g = merge_df.loc[merge_df["Mouse ID"] == "g989", :]
duplicate_mouse_g
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint
# 908     g989     Propriva  Female          21          26          0  \
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1
# 918           56.045564                 1
# 919           59.082294                 1
# 920           62.570880                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merge_df.loc[merge_df["Mouse ID"] != "g989",:]
clean_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint
# 0     k403     Ramicane  Male          21          16          0  \
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_df["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
drug_regimen = clean_df.groupby('Drug Regimen')
dr_mean = drug_regimen['Tumor Volume (mm3)'].mean()
dr_median = drug_regimen['Tumor Volume (mm3)'].median()
dr_var = drug_regimen['Tumor Volume (mm3)'].var()
dr_std = drug_regimen['Tumor Volume (mm3)'].std()
dr_sem = drug_regimen['Tumor Volume (mm3)'].sem()

drug_regimen_df = pd.DataFrame({
    "Mean Tumor Volume":dr_mean,
    "Median Tumor Volume":dr_median,
    "Tumor Volume Variance":dr_var,
    "Tumor Volume Std. Dev.":dr_std,
    "Tumor Volume Std. Err.":dr_sem
})

drug_regimen_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764  \
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   4.994774                0.329346
# Ceftamin                    6.268188                0.469821
# Infubinol                   6.567243                0.492236
# Ketapril                    8.279709                0.603860
# Naftisol                    8.134708                0.596466
# Placebo                     7.821003                0.581331
# Propriva                    6.622085                0.544332
# Ramicane                    4.846308                0.320955
# Stelasyn                    7.710419                0.573111
# Zoniferol                   6.966589                0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
drug_regimen_df_agg = pd.DataFrame(clean_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].agg(Mean='mean',Median='median',Var='var',Std='std',Sem='sem'))
drug_regimen_df_agg
# Out:
#                    Mean     Median        Var       Std       Sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
dr_id_tp = clean_df[['Drug Regimen','Mouse ID']]
dr_data = dr_id_tp['Drug Regimen'].value_counts()
figure1 = dr_data.plot(kind = "bar",
                      xlabel='Drug Regimen',
                      ylabel='# of Observed Mouse Timepoints')

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
figure2 = plt.bar(dr_data.index, dr_data.values, align="center")
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')
plt.xticks(rotation=90)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
# labels = [value for value in clean_df['Sex'].unique()]
labels = ["Female","Male"]
mice_count = len(clean_df["Mouse ID"].unique())
fm_data = clean_df.groupby('Sex').nunique()
fm_percent = (fm_data['Mouse ID']/mice_count*100)
pie_chart = fm_percent.plot.pie(label=labels,autopct="%1.1f%%")
pie_chart.set_ylabel('')
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 7
#       5 fm_data = clean_df.groupby('Sex').nunique()
#       6 fm_percent = (fm_data['Mouse ID']/mice_count*100)
# ----> 7 pie_chart = fm_percent.plot.pie(label=labels,autopct="%1.1f%%")
#       8 pie_chart.set_ylabel('')
#       9 plt.axis('equal')
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\plotting\_core.py:1589, in PlotAccessor.pie(self, **kwargs)
#    1583 if (
#    1584     isinstance(self._parent, ABCDataFrame)
#    1585     and kwargs.get("y", None) is None
#    1586     and not kwargs.get("subplots", False)
#    1587 ):
#    1588     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1589 return self(kind="pie", **kwargs)
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1834, in PiePlot._make_plot(self)
#    1831 colors = self._get_colors(num_colors=len(self.data), color_kwds="colors")
#    1832 self.kwds.setdefault("colors", colors)
# -> 1834 for i, (label, y) in enumerate(self._iter_data()):
#    1835     ax = self._get_ax(i)
#    1836     if label is not None:
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:422, in MPLPlot._iter_data(self, data, keep_index, fillna)
#     419 if fillna is not None:
#     420     data = data.fillna(fillna)
# --> 422 for col, values in data.items():
#     423     if keep_index is True:
#     424         yield col, values
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\frame.py:1347, in DataFrame.items(self)
#    1345 @Appender(_shared_docs["items"])
#    1346 def items(self) -> Iterable[tuple[Hashable, Series]]:
# -> 1347     if self.columns.is_unique and hasattr(self, "_item_cache"):
#    1348         for k in self.columns:
#    1349             yield k, self._get_item_cache(k)
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2238, in Index.is_unique(self)
#    2205 @cache_readonly
#    2206 def is_unique(self) -> bool:
#    2207     """
#    2208     Return if the index has unique values.
#    2209
#    (...)
#    2236     True
#    2237     """
# -> 2238     return self._engine.is_unique
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\_libs\index.pyx:236, in pandas._libs.index.IndexEngine.is_unique.__get__()
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\_libs\index.pyx:241, in pandas._libs.index.IndexEngine._do_unique_check()
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\_libs\index.pyx:303, in pandas._libs.index.IndexEngine._ensure_mapping_populated()
#
# File pandas\_libs\hashtable_class_helper.pxi:7114, in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(fm_percent, labels=labels,
        autopct="%1.1f%%", shadow=True, startangle=0)
plt.show()
# Out:
# Sex
# Female    49.596774
# Male      50.403226
# Name: Mouse ID, dtype: float64

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = clean_df.loc[clean_df['Mouse ID'].unique(),max(clean_df['Timepoint'])]

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 45
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 5
#       1 # Calculate the final tumor volume of each mouse across four of the treatment regimens:
#       2 # Capomulin, Ramicane, Infubinol, and Ceftamin
#       3
#       4 # Start by getting the last (greatest) timepoint for each mouse
# ----> 5 last_timepoint = clean_df.loc[clean_df['Mouse ID'].unique(),max(clean_df['Timepoint'])]
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\indexing.py:1000, in _LocationIndexer._getitem_lowerdim(self, tup)
#     996 for i, key in enumerate(tup):
#     997     if is_label_like(key):
#     998         # We don't need to check for tuples here because those are
#     999         #  caught by the _is_nested_tuple_indexer check above.
# -> 1000         section = self._getitem_axis(key, axis=i)
#    1002         # We should never have a scalar section here, because
#    1003         #  _getitem_lowerdim is only called after a check for
#    1004         #  is_scalar_access, which that would be.
#    1005         if section.ndim == self.ndim:
#    1006             # we're in the middle of slicing through a MultiIndex
#    1007             # revise the key wrt to `section` by inserting an _NS
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\generic.py:4082, in NDFrame.xs(self, key, axis, level, drop_level)
#    4080 if axis == 1:
#    4081     if drop_level:
# -> 4082         return self[key]
#    4083     index = self.columns
#    4084 else:
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\jkoo0\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 45

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 

    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
